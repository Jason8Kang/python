# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 44666.945312, Training Accuracy= 0.17188
# Iter 2560, Minibatch Loss= 11236.121094, Training Accuracy= 0.48438
# Iter 3840, Minibatch Loss= 9483.634766, Training Accuracy= 0.60938
# Iter 5120, Minibatch Loss= 6126.700684, Training Accuracy= 0.71875
# Iter 6400, Minibatch Loss= 5654.581055, Training Accuracy= 0.77344
# Iter 7680, Minibatch Loss= 6981.930176, Training Accuracy= 0.71094
# Iter 8960, Minibatch Loss= 3981.873535, Training Accuracy= 0.81250
# Iter 10240, Minibatch Loss= 5144.403809, Training Accuracy= 0.81250
# Iter 11520, Minibatch Loss= 3565.977051, Training Accuracy= 0.90625
# Iter 12800, Minibatch Loss= 3709.069824, Training Accuracy= 0.84375
# Iter 14080, Minibatch Loss= 1657.204590, Training Accuracy= 0.90625
# Iter 15360, Minibatch Loss= 1847.302490, Training Accuracy= 0.93750
# Iter 16640, Minibatch Loss= 2486.811035, Training Accuracy= 0.87500
# Iter 17920, Minibatch Loss= 1593.272949, Training Accuracy= 0.90625
# Iter 19200, Minibatch Loss= 1399.693970, Training Accuracy= 0.92969
# Iter 20480, Minibatch Loss= 570.069275, Training Accuracy= 0.95312
# Iter 21760, Minibatch Loss= 4082.443604, Training Accuracy= 0.83594
# Iter 23040, Minibatch Loss= 1374.451050, Training Accuracy= 0.96094
# Iter 24320, Minibatch Loss= 2023.177734, Training Accuracy= 0.91406
# Iter 25600, Minibatch Loss= 1923.943359, Training Accuracy= 0.88281
# Iter 26880, Minibatch Loss= 1215.327393, Training Accuracy= 0.93750
# Iter 28160, Minibatch Loss= 1150.111938, Training Accuracy= 0.93750
# Iter 29440, Minibatch Loss= 1203.400391, Training Accuracy= 0.94531
# Iter 30720, Minibatch Loss= 1235.724365, Training Accuracy= 0.90625
# Iter 32000, Minibatch Loss= 1375.621826, Training Accuracy= 0.89062
# Iter 33280, Minibatch Loss= 154.272430, Training Accuracy= 0.96875
# Iter 34560, Minibatch Loss= 1223.380859, Training Accuracy= 0.92969
# Iter 35840, Minibatch Loss= 651.861572, Training Accuracy= 0.94531
# Iter 37120, Minibatch Loss= 1499.580566, Training Accuracy= 0.92188
# Iter 38400, Minibatch Loss= 63.335861, Training Accuracy= 0.97656
# Iter 39680, Minibatch Loss= 351.686981, Training Accuracy= 0.96875
# Iter 40960, Minibatch Loss= 2221.053467, Training Accuracy= 0.89062
# Iter 42240, Minibatch Loss= 821.099182, Training Accuracy= 0.93750
# Iter 43520, Minibatch Loss= 740.679321, Training Accuracy= 0.96094
# Iter 44800, Minibatch Loss= 257.620117, Training Accuracy= 0.95312
# Iter 46080, Minibatch Loss= 305.622864, Training Accuracy= 0.94531
# Iter 47360, Minibatch Loss= 961.234375, Training Accuracy= 0.94531
# Iter 48640, Minibatch Loss= 1989.188599, Training Accuracy= 0.89844
# Iter 49920, Minibatch Loss= 1898.271484, Training Accuracy= 0.87500
# Iter 51200, Minibatch Loss= 24.239777, Training Accuracy= 0.98438
# Iter 52480, Minibatch Loss= 336.248047, Training Accuracy= 0.96875
# Iter 53760, Minibatch Loss= 289.948395, Training Accuracy= 0.96875
# Iter 55040, Minibatch Loss= 746.371033, Training Accuracy= 0.96094
# Iter 56320, Minibatch Loss= 528.888428, Training Accuracy= 0.94531
# Iter 57600, Minibatch Loss= 726.608948, Training Accuracy= 0.93750
# Iter 58880, Minibatch Loss= 101.641418, Training Accuracy= 0.97656
# Iter 60160, Minibatch Loss= 635.841553, Training Accuracy= 0.94531
# Iter 61440, Minibatch Loss= 844.735779, Training Accuracy= 0.92969
# Iter 62720, Minibatch Loss= 1480.216187, Training Accuracy= 0.90625
# Iter 64000, Minibatch Loss= 1116.103638, Training Accuracy= 0.92188
# Iter 65280, Minibatch Loss= 400.637756, Training Accuracy= 0.97656
# Iter 66560, Minibatch Loss= 383.323730, Training Accuracy= 0.94531
# Iter 67840, Minibatch Loss= 720.705444, Training Accuracy= 0.93750
# Iter 69120, Minibatch Loss= 444.355560, Training Accuracy= 0.95312
# Iter 70400, Minibatch Loss= 568.989502, Training Accuracy= 0.96094
# Iter 71680, Minibatch Loss= 1161.661621, Training Accuracy= 0.93750
# Iter 72960, Minibatch Loss= 124.189392, Training Accuracy= 0.96875
# Iter 74240, Minibatch Loss= 244.537338, Training Accuracy= 0.96875
# Iter 75520, Minibatch Loss= 516.234131, Training Accuracy= 0.96094
# Iter 76800, Minibatch Loss= 647.562988, Training Accuracy= 0.95312
# Iter 78080, Minibatch Loss= 674.703613, Training Accuracy= 0.93750
# Iter 79360, Minibatch Loss= 478.306915, Training Accuracy= 0.96094
# Iter 80640, Minibatch Loss= 828.887939, Training Accuracy= 0.96094
# Iter 81920, Minibatch Loss= 831.571350, Training Accuracy= 0.92188
# Iter 83200, Minibatch Loss= 1139.901123, Training Accuracy= 0.93750
# Iter 84480, Minibatch Loss= 572.590149, Training Accuracy= 0.96875
# Iter 85760, Minibatch Loss= 424.528503, Training Accuracy= 0.96875
# Iter 87040, Minibatch Loss= 520.733276, Training Accuracy= 0.96094
# Iter 88320, Minibatch Loss= 325.530334, Training Accuracy= 0.96094
# Iter 89600, Minibatch Loss= 596.970825, Training Accuracy= 0.96094
# Iter 90880, Minibatch Loss= 31.020096, Training Accuracy= 0.97656
# Iter 92160, Minibatch Loss= 627.413147, Training Accuracy= 0.93750
# Iter 93440, Minibatch Loss= 174.948227, Training Accuracy= 0.97656
# Iter 94720, Minibatch Loss= 92.232712, Training Accuracy= 0.98438
# Iter 96000, Minibatch Loss= 571.470825, Training Accuracy= 0.94531
# Iter 97280, Minibatch Loss= 259.027405, Training Accuracy= 0.96094
# Iter 98560, Minibatch Loss= 233.332794, Training Accuracy= 0.97656
# Iter 99840, Minibatch Loss= 299.626770, Training Accuracy= 0.98438
# Iter 101120, Minibatch Loss= 627.985657, Training Accuracy= 0.94531
# Iter 102400, Minibatch Loss= 545.265747, Training Accuracy= 0.96094
# Iter 103680, Minibatch Loss= 298.539307, Training Accuracy= 0.96094
# Iter 104960, Minibatch Loss= 776.211548, Training Accuracy= 0.96875
# Iter 106240, Minibatch Loss= 313.775940, Training Accuracy= 0.97656
# Iter 107520, Minibatch Loss= 572.240845, Training Accuracy= 0.95312
# Iter 108800, Minibatch Loss= 790.182190, Training Accuracy= 0.96094
# Iter 110080, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 111360, Minibatch Loss= 333.643982, Training Accuracy= 0.94531
# Iter 112640, Minibatch Loss= 685.334839, Training Accuracy= 0.92188
# Iter 113920, Minibatch Loss= 172.774094, Training Accuracy= 0.97656
# Iter 115200, Minibatch Loss= 192.061279, Training Accuracy= 0.97656
# Iter 116480, Minibatch Loss= 209.241013, Training Accuracy= 0.97656
# Iter 117760, Minibatch Loss= 453.569275, Training Accuracy= 0.93750
# Iter 119040, Minibatch Loss= 47.464905, Training Accuracy= 0.98438
# Iter 120320, Minibatch Loss= 547.134155, Training Accuracy= 0.98438
# Iter 121600, Minibatch Loss= 575.305420, Training Accuracy= 0.96875
# Iter 122880, Minibatch Loss= 634.023315, Training Accuracy= 0.93750
# Iter 124160, Minibatch Loss= 160.505066, Training Accuracy= 0.96875
# Iter 125440, Minibatch Loss= 280.080688, Training Accuracy= 0.96094
# Iter 126720, Minibatch Loss= 217.448837, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 520.372864, Training Accuracy= 0.93750
# Iter 129280, Minibatch Loss= 280.730560, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 212.289581, Training Accuracy= 0.98438
# Iter 131840, Minibatch Loss= 216.647873, Training Accuracy= 0.95312
# Iter 133120, Minibatch Loss= 54.001953, Training Accuracy= 0.99219
# Iter 134400, Minibatch Loss= 480.630798, Training Accuracy= 0.95312
# Iter 135680, Minibatch Loss= 202.255722, Training Accuracy= 0.98438
# Iter 136960, Minibatch Loss= 36.623009, Training Accuracy= 0.99219
# Iter 138240, Minibatch Loss= 461.928528, Training Accuracy= 0.96875
# Iter 139520, Minibatch Loss= 198.446976, Training Accuracy= 0.96875
# Iter 140800, Minibatch Loss= 73.628487, Training Accuracy= 0.97656
# Iter 142080, Minibatch Loss= 785.542175, Training Accuracy= 0.93750
# Iter 143360, Minibatch Loss= 102.649765, Training Accuracy= 0.98438
# Iter 144640, Minibatch Loss= 399.677429, Training Accuracy= 0.92969
# Iter 145920, Minibatch Loss= 374.253387, Training Accuracy= 0.94531
# Iter 147200, Minibatch Loss= 289.314117, Training Accuracy= 0.97656
# Iter 148480, Minibatch Loss= 144.058823, Training Accuracy= 0.98438
# Iter 149760, Minibatch Loss= 354.883118, Training Accuracy= 0.98438
# Iter 151040, Minibatch Loss= 853.520020, Training Accuracy= 0.93750
# Iter 152320, Minibatch Loss= 318.063660, Training Accuracy= 0.95312
# Iter 153600, Minibatch Loss= 483.822205, Training Accuracy= 0.95312
# Iter 154880, Minibatch Loss= 123.922058, Training Accuracy= 0.98438
# Iter 156160, Minibatch Loss= 243.028015, Training Accuracy= 0.95312
# Iter 157440, Minibatch Loss= 47.799347, Training Accuracy= 0.99219
# Iter 158720, Minibatch Loss= 426.634918, Training Accuracy= 0.96094
# Iter 160000, Minibatch Loss= 32.336700, Training Accuracy= 0.99219
# Iter 161280, Minibatch Loss= 0.165466, Training Accuracy= 0.99219
# Iter 162560, Minibatch Loss= 45.004303, Training Accuracy= 0.99219
# Iter 163840, Minibatch Loss= 979.970398, Training Accuracy= 0.94531
# Iter 165120, Minibatch Loss= 544.256104, Training Accuracy= 0.93750
# Iter 166400, Minibatch Loss= 140.621078, Training Accuracy= 0.96875
# Iter 167680, Minibatch Loss= 10.224045, Training Accuracy= 0.99219
# Iter 168960, Minibatch Loss= 108.960052, Training Accuracy= 0.97656
# Iter 170240, Minibatch Loss= 309.500671, Training Accuracy= 0.94531
# Iter 171520, Minibatch Loss= 58.510525, Training Accuracy= 0.98438
# Iter 172800, Minibatch Loss= 0.294327, Training Accuracy= 0.99219
# Iter 174080, Minibatch Loss= 495.950256, Training Accuracy= 0.94531
# Iter 175360, Minibatch Loss= 288.575012, Training Accuracy= 0.98438
# Iter 176640, Minibatch Loss= 210.572250, Training Accuracy= 0.96875
# Iter 177920, Minibatch Loss= 121.407974, Training Accuracy= 0.97656
# Iter 179200, Minibatch Loss= 295.807251, Training Accuracy= 0.96094
# Iter 180480, Minibatch Loss= 228.614441, Training Accuracy= 0.98438
# Iter 181760, Minibatch Loss= 174.289627, Training Accuracy= 0.98438
# Iter 183040, Minibatch Loss= 79.931908, Training Accuracy= 0.99219
# Iter 184320, Minibatch Loss= 68.438507, Training Accuracy= 0.98438
# Iter 185600, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 186880, Minibatch Loss= 183.818634, Training Accuracy= 0.97656
# Iter 188160, Minibatch Loss= 108.312569, Training Accuracy= 0.96875
# Iter 189440, Minibatch Loss= 58.432068, Training Accuracy= 0.99219
# Iter 190720, Minibatch Loss= 215.612305, Training Accuracy= 0.96875
# Iter 192000, Minibatch Loss= 133.841614, Training Accuracy= 0.96875
# Iter 193280, Minibatch Loss= 17.021759, Training Accuracy= 0.99219
# Iter 194560, Minibatch Loss= 156.004410, Training Accuracy= 0.99219
# Iter 195840, Minibatch Loss= 387.131744, Training Accuracy= 0.97656
# Iter 197120, Minibatch Loss= 119.444641, Training Accuracy= 0.98438
# Iter 198400, Minibatch Loss= 438.718384, Training Accuracy= 0.96094
# Iter 199680, Minibatch Loss= 246.295853, Training Accuracy= 0.95312
# Optimization Finished!
# Testing Accuracy: 0.980469

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter 1280, Minibatch Loss= 26065.507812, Training Accuracy= 0.27344
# Iter 2560, Minibatch Loss= 12848.732422, Training Accuracy= 0.45312
# Iter 3840, Minibatch Loss= 8218.185547, Training Accuracy= 0.62500
# Iter 5120, Minibatch Loss= 3485.873291, Training Accuracy= 0.78125
# Iter 6400, Minibatch Loss= 2393.453369, Training Accuracy= 0.82812
# Iter 7680, Minibatch Loss= 6900.361328, Training Accuracy= 0.71875
# Iter 8960, Minibatch Loss= 2583.133545, Training Accuracy= 0.78906
# Iter 10240, Minibatch Loss= 3039.738281, Training Accuracy= 0.84375
# Iter 11520, Minibatch Loss= 1388.218262, Training Accuracy= 0.89844
# Iter 12800, Minibatch Loss= 2743.423828, Training Accuracy= 0.82031
# Iter 14080, Minibatch Loss= 1027.255615, Training Accuracy= 0.89844
# Iter 15360, Minibatch Loss= 1904.680054, Training Accuracy= 0.89844
# Iter 16640, Minibatch Loss= 1865.132812, Training Accuracy= 0.89844
# Iter 17920, Minibatch Loss= 970.443176, Training Accuracy= 0.91406
# Iter 19200, Minibatch Loss= 1234.875000, Training Accuracy= 0.92969
# Iter 20480, Minibatch Loss= 704.196716, Training Accuracy= 0.96094
# Iter 21760, Minibatch Loss= 2752.845459, Training Accuracy= 0.82812
# Iter 23040, Minibatch Loss= 933.562988, Training Accuracy= 0.92969
# Iter 24320, Minibatch Loss= 1285.864746, Training Accuracy= 0.90625
# Iter 25600, Minibatch Loss= 1640.043335, Training Accuracy= 0.89062
# Iter 26880, Minibatch Loss= 1131.178711, Training Accuracy= 0.89844
# Iter 28160, Minibatch Loss= 1020.291626, Training Accuracy= 0.92969
# Iter 29440, Minibatch Loss= 1143.347900, Training Accuracy= 0.92188
# Iter 30720, Minibatch Loss= 1015.739990, Training Accuracy= 0.91406
# Iter 32000, Minibatch Loss= 580.690430, Training Accuracy= 0.93750
# Iter 33280, Minibatch Loss= 499.575623, Training Accuracy= 0.92188
# Iter 34560, Minibatch Loss= 230.748795, Training Accuracy= 0.97656
# Iter 35840, Minibatch Loss= 314.040039, Training Accuracy= 0.93750
# Iter 37120, Minibatch Loss= 863.996094, Training Accuracy= 0.89844
# Iter 38400, Minibatch Loss= 12.816391, Training Accuracy= 0.98438
# Iter 39680, Minibatch Loss= 276.944366, Training Accuracy= 0.96875
# Iter 40960, Minibatch Loss= 1349.445801, Training Accuracy= 0.90625
# Iter 42240, Minibatch Loss= 324.158112, Training Accuracy= 0.92969
# Iter 43520, Minibatch Loss= 286.037231, Training Accuracy= 0.94531
# Iter 44800, Minibatch Loss= 486.993896, Training Accuracy= 0.94531
# Iter 46080, Minibatch Loss= 258.495850, Training Accuracy= 0.96875
# Iter 47360, Minibatch Loss= 1076.495850, Training Accuracy= 0.92969
# Iter 48640, Minibatch Loss= 1427.723999, Training Accuracy= 0.91406
# Iter 49920, Minibatch Loss= 568.407776, Training Accuracy= 0.92188
# Iter 51200, Minibatch Loss= 121.061172, Training Accuracy= 0.97656
# Iter 52480, Minibatch Loss= 54.472626, Training Accuracy= 0.98438
# Iter 53760, Minibatch Loss= 154.706833, Training Accuracy= 0.99219
# Iter 55040, Minibatch Loss= 1153.489990, Training Accuracy= 0.93750
# Iter 56320, Minibatch Loss= 446.412476, Training Accuracy= 0.92188
# Iter 57600, Minibatch Loss= 1285.730957, Training Accuracy= 0.92188
# Iter 58880, Minibatch Loss= 939.597168, Training Accuracy= 0.92188
# Iter 60160, Minibatch Loss= 488.368805, Training Accuracy= 0.96875
# Iter 61440, Minibatch Loss= 428.892792, Training Accuracy= 0.96094
# Iter 62720, Minibatch Loss= 625.985474, Training Accuracy= 0.95312
# Iter 64000, Minibatch Loss= 934.420349, Training Accuracy= 0.95312
# Iter 65280, Minibatch Loss= 197.021606, Training Accuracy= 0.96094
# Iter 66560, Minibatch Loss= 674.801758, Training Accuracy= 0.93750
# Iter 67840, Minibatch Loss= 379.964966, Training Accuracy= 0.95312
# Iter 69120, Minibatch Loss= 174.250656, Training Accuracy= 0.95312
# Iter 70400, Minibatch Loss= 401.814270, Training Accuracy= 0.95312
# Iter 71680, Minibatch Loss= 328.278839, Training Accuracy= 0.96094
# Iter 72960, Minibatch Loss= 876.219727, Training Accuracy= 0.94531
# Iter 74240, Minibatch Loss= 472.186737, Training Accuracy= 0.92188
# Iter 75520, Minibatch Loss= 597.634460, Training Accuracy= 0.96094
# Iter 76800, Minibatch Loss= 849.679688, Training Accuracy= 0.95312
# Iter 78080, Minibatch Loss= 692.164246, Training Accuracy= 0.94531
# Iter 79360, Minibatch Loss= 433.447571, Training Accuracy= 0.95312
# Iter 80640, Minibatch Loss= 289.322266, Training Accuracy= 0.96094
# Iter 81920, Minibatch Loss= 234.357483, Training Accuracy= 0.97656
# Iter 83200, Minibatch Loss= 260.360474, Training Accuracy= 0.94531
# Iter 84480, Minibatch Loss= 420.279572, Training Accuracy= 0.95312
# Iter 85760, Minibatch Loss= 471.964996, Training Accuracy= 0.96094
# Iter 87040, Minibatch Loss= 48.804825, Training Accuracy= 0.98438
# Iter 88320, Minibatch Loss= 289.571014, Training Accuracy= 0.96875
# Iter 89600, Minibatch Loss= 297.418091, Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 394.935303, Training Accuracy= 0.95312
# Iter 92160, Minibatch Loss= 495.918640, Training Accuracy= 0.96094
# Iter 93440, Minibatch Loss= 272.135132, Training Accuracy= 0.96875
# Iter 94720, Minibatch Loss= 32.052795, Training Accuracy= 0.99219
# Iter 96000, Minibatch Loss= 573.723877, Training Accuracy= 0.96094
# Iter 97280, Minibatch Loss= 251.229935, Training Accuracy= 0.98438
# Iter 98560, Minibatch Loss= 103.668190, Training Accuracy= 0.98438
# Iter 99840, Minibatch Loss= 542.945374, Training Accuracy= 0.95312
# Iter 101120, Minibatch Loss= 129.132721, Training Accuracy= 0.95312
# Iter 102400, Minibatch Loss= 289.863983, Training Accuracy= 0.95312
# Iter 103680, Minibatch Loss= 690.814819, Training Accuracy= 0.94531
# Iter 104960, Minibatch Loss= 248.490448, Training Accuracy= 0.96875
# Iter 106240, Minibatch Loss= 450.820831, Training Accuracy= 0.94531
# Iter 107520, Minibatch Loss= 298.571899, Training Accuracy= 0.96094
# Iter 108800, Minibatch Loss= 414.365662, Training Accuracy= 0.96875
# Iter 110080, Minibatch Loss= 246.818848, Training Accuracy= 0.96875
# Iter 111360, Minibatch Loss= 242.406677, Training Accuracy= 0.94531
# Iter 112640, Minibatch Loss= 39.124268, Training Accuracy= 0.98438
# Iter 113920, Minibatch Loss= 130.132538, Training Accuracy= 0.96875
# Iter 115200, Minibatch Loss= 254.306107, Training Accuracy= 0.96094
# Iter 116480, Minibatch Loss= 82.006302, Training Accuracy= 0.99219
# Iter 117760, Minibatch Loss= 134.090347, Training Accuracy= 0.97656
# Iter 119040, Minibatch Loss= 638.739502, Training Accuracy= 0.94531
# Iter 120320, Minibatch Loss= 767.868347, Training Accuracy= 0.92188
# Iter 121600, Minibatch Loss= 31.695221, Training Accuracy= 0.99219
# Iter 122880, Minibatch Loss= 57.208954, Training Accuracy= 0.97656
# Iter 124160, Minibatch Loss= 336.430054, Training Accuracy= 0.98438
# Iter 125440, Minibatch Loss= 206.514526, Training Accuracy= 0.96094
# Iter 126720, Minibatch Loss= 277.760956, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 134.151062, Training Accuracy= 0.96875
# Iter 129280, Minibatch Loss= 8.978619, Training Accuracy= 0.99219
# Iter 130560, Minibatch Loss= 538.018066, Training Accuracy= 0.96094
# Iter 131840, Minibatch Loss= 405.037933, Training Accuracy= 0.96094
# Iter 133120, Minibatch Loss= 99.936073, Training Accuracy= 0.96875
# Iter 134400, Minibatch Loss= 262.980347, Training Accuracy= 0.96875
# Iter 135680, Minibatch Loss= 116.117439, Training Accuracy= 0.96094
# Iter 136960, Minibatch Loss= 80.737968, Training Accuracy= 0.96875
# Iter 138240, Minibatch Loss= 252.706192, Training Accuracy= 0.96094
# Iter 139520, Minibatch Loss= 27.555397, Training Accuracy= 0.99219
# Iter 140800, Minibatch Loss= 345.229797, Training Accuracy= 0.94531
# Iter 142080, Minibatch Loss= 140.962158, Training Accuracy= 0.99219
# Iter 143360, Minibatch Loss= 217.054260, Training Accuracy= 0.98438
# Iter 144640, Minibatch Loss= 158.976105, Training Accuracy= 0.97656
# Iter 145920, Minibatch Loss= 196.679749, Training Accuracy= 0.97656
# Iter 147200, Minibatch Loss= 309.177521, Training Accuracy= 0.95312
# Iter 148480, Minibatch Loss= 20.233719, Training Accuracy= 0.99219
# Iter 149760, Minibatch Loss= 169.731018, Training Accuracy= 0.98438
# Iter 151040, Minibatch Loss= 88.581741, Training Accuracy= 0.96875
# Iter 152320, Minibatch Loss= 284.921967, Training Accuracy= 0.96875
# Iter 153600, Minibatch Loss= 436.912292, Training Accuracy= 0.97656
# Iter 154880, Minibatch Loss= 92.779259, Training Accuracy= 0.96094
# Iter 156160, Minibatch Loss= 142.682388, Training Accuracy= 0.96875
# Iter 157440, Minibatch Loss= 265.149780, Training Accuracy= 0.96094
# Iter 158720, Minibatch Loss= 307.641663, Training Accuracy= 0.96094
# Iter 160000, Minibatch Loss= 75.190613, Training Accuracy= 0.96875
# Iter 161280, Minibatch Loss= 213.799713, Training Accuracy= 0.98438
# Iter 162560, Minibatch Loss= 161.761780, Training Accuracy= 0.96875
# Iter 163840, Minibatch Loss= 2.598106, Training Accuracy= 0.99219
# Iter 165120, Minibatch Loss= 254.702484, Training Accuracy= 0.96875
# Iter 166400, Minibatch Loss= 17.656181, Training Accuracy= 0.95312
# Iter 167680, Minibatch Loss= 205.016388, Training Accuracy= 0.96875
# Iter 168960, Minibatch Loss= 66.018051, Training Accuracy= 0.98438
# Iter 170240, Minibatch Loss= 166.613953, Training Accuracy= 0.96875
# Iter 171520, Minibatch Loss= 88.066185, Training Accuracy= 0.99219
# Iter 172800, Minibatch Loss= 30.446144, Training Accuracy= 0.99219
# Iter 174080, Minibatch Loss= 108.064949, Training Accuracy= 0.98438
# Iter 175360, Minibatch Loss= 374.926605, Training Accuracy= 0.95312
# Iter 176640, Minibatch Loss= 244.045898, Training Accuracy= 0.96094
# Iter 177920, Minibatch Loss= 310.896942, Training Accuracy= 0.95312
# Iter 179200, Minibatch Loss= 119.788483, Training Accuracy= 0.98438
# Iter 180480, Minibatch Loss= 118.914001, Training Accuracy= 0.98438
# Iter 181760, Minibatch Loss= 178.472946, Training Accuracy= 0.97656
# Iter 183040, Minibatch Loss= 70.008606, Training Accuracy= 0.96875
# Iter 184320, Minibatch Loss= 182.874237, Training Accuracy= 0.96875
# Iter 185600, Minibatch Loss= 5.796143, Training Accuracy= 0.99219
# Iter 186880, Minibatch Loss= 48.669418, Training Accuracy= 0.98438
# Iter 188160, Minibatch Loss= 39.061050, Training Accuracy= 0.98438
# Iter 189440, Minibatch Loss= 186.353745, Training Accuracy= 0.96875
# Iter 190720, Minibatch Loss= 99.739151, Training Accuracy= 0.97656
# Iter 192000, Minibatch Loss= 42.721718, Training Accuracy= 0.97656
# Iter 193280, Minibatch Loss= 327.810913, Training Accuracy= 0.96094
# Iter 194560, Minibatch Loss= 14.808701, Training Accuracy= 0.99219
# Iter 195840, Minibatch Loss= 35.609268, Training Accuracy= 0.99219
# Iter 197120, Minibatch Loss= 55.640175, Training Accuracy= 0.97656
# Iter 198400, Minibatch Loss= 43.397263, Training Accuracy= 0.99219
# Iter 199680, Minibatch Loss= 7.038841, Training Accuracy= 0.99219
# Optimization Finished!
# Testing Accuracy: 0.988281

# %%
# Out:
# 2
