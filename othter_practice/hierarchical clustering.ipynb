# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np

# %matplotlib inline
np.set_printoptions(precision=5, suppress=True)

# %%
# 生成两个集群: 集群 a 有100个数据点, 集群 b 有50个数据点:
np.random.seed(1029)
a = np.random.multivariate_normal([10,5,0], [[1, 0, 0], [0,1,0], [0,0,1]], size=100)
b = np.random.multivariate_normal([0,0,0 ], [[1, 0, 0], [0,1,0], [0,0,1]], size=100)
X = np.concatenate((a, b),)
X.shape
# Out:
# (200L, 3L)

# %%
plt.figure(figsize=(25, 10))
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
linkage?

# %%
# 建立集群关系数组
Z = linkage(X, 'ward')
print Z.shape
print Z
# Out:
# (199L, 4L)
# [[ 116.       124.         0.08708    2.     ]
#  [ 110.       130.         0.09489    2.     ]
#  [  22.        48.         0.10588    2.     ]
#  [  12.        33.         0.17892    2.     ]
#  [  31.        98.         0.18948    2.     ]
#  [ 194.       198.         0.19127    2.     ]
#  [ 102.       114.         0.19664    2.     ]
#  [ 105.       178.         0.20746    2.     ]
#  [  24.        36.         0.21547    2.     ]
#  [ 112.       187.         0.22618    2.     ]
#  [ 139.       156.         0.23322    2.     ]
#  [ 104.       165.         0.25841    2.     ]
#  [ 123.       146.         0.25844    2.     ]
#  [  21.        57.         0.2679     2.     ]
#  [ 131.       151.         0.27065    2.     ]
#  [  59.        97.         0.27339    2.     ]
#  [   1.        65.         0.27704    2.     ]
#  [  19.       203.         0.28026    3.     ]
#  [ 183.       186.         0.28063    2.     ]
#  [ 122.       169.         0.2904     2.     ]
# ...

# %%
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

c, coph_dists = cophenet(Z, pdist(X))
print c
# Out:
# 0.976108728523

# %%
plt.figure(figsize=(50, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(Z, leaf_rotation=90., leaf_font_size=8.
)
plt.show()

# %%
import pandas as pd
data=pd.read_csv('C:/Users/17031172/Documents/R/R-scorecard-master/german_credit.csv')
data.describe()
# Out:
#        Creditability  AccountBalance     Duration  \
# count    1000.000000     1000.000000  1000.000000
# mean        0.700000        2.577000    20.903000
# std         0.458487        1.257638    12.058814
# min         0.000000        1.000000     4.000000
# 25%         0.000000        1.000000    12.000000
# 50%         1.000000        2.000000    18.000000
# 75%         1.000000        4.000000    24.000000
# max         1.000000        4.000000    72.000000
#
#        PaymentStatusofPreviousCredit      Purpose  CreditAmount  ValueSavings  \
# count                     1000.00000  1000.000000    1000.00000   1000.000000
# mean                         2.54500     2.828000    3271.24800      2.105000
# std                          1.08312     2.744439    2822.75176      1.580023
# min                          0.00000     0.000000     250.00000      1.000000
# 25%                          2.00000     1.000000    1365.50000      1.000000
# ...

# %%
linkage(data[['Creditability','AccountBalance','Duration','PaymentStatusofPreviousCredit']])
# Out:
# array([[    0.     ,   586.     ,     0.     ,     2.     ],
#        [  523.     ,   528.     ,     0.     ,     2.     ],
#        [  524.     ,   619.     ,     0.     ,     2.     ],
#        ...,
#        [ 1988.     ,  1995.     ,     6.     ,   986.     ],
#        [ 1981.     ,  1996.     ,     6.08276,   999.     ],
#        [  719.     ,  1997.     ,    12.     ,  1000.     ]])

# %%
import pickle 
a=1
exec("with open('test.txt','wb') as AutoPickleFile:\n\t pickle.dump(a,AutoPickleFile)")

# %%
import numpy as np
import matplotlib.pyplot as plt
p=np.arange(0.00001,0.99999,0.001)
plt.plot(p,-np.log10(1/p-1))

# %%
# Out:
# 0.09090909090909091
